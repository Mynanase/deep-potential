# %% [markdown]
# # Figure debugging
# This notebook reads saved JSON/NPZ artifacts. It never trains or evaluates a model.

# %%
from experiments.plotting import render_figure, write_figure

RUN = "configs/runs/plummer_rcut_full.yaml"

# %% [markdown]
# ## Training

# %%
fig = render_figure(RUN, "training_df")
fig

# %%
fig = render_figure(RUN, "training_phi")
fig

# %%
fig = render_figure(RUN, "training_df_score_stats")
fig

# %%
fig = render_figure(RUN, "training_phi_residual_stats")
fig

# %% [markdown]
# ## DF

# %%
fig = render_figure(RUN, "df_density_profile")
fig

# %%
fig = render_figure(RUN, "df_cylindrical_rz_density")
fig

# %%
fig = render_figure(
    RUN,
    "df_cylindrical_marginals_by_R",
    overrides={"length_unit": "", "velocity_unit": ""},
)
fig

# %%
fig = render_figure(
    RUN,
    "df_score_field_rv",
    overrides={"min_effective_count": 10},
)
fig

# %%
fig = render_figure(RUN, "df_score_slices_by_R")
fig

# %%
fig = render_figure(RUN, "df_radial_speed_density")
fig

# %% [markdown]
# ## Phi

# %%
fig = render_figure(RUN, "phi_potential_profile")
fig

# %%
fig = render_figure(RUN, "phi_acceleration_profile")
fig

# %%
fig = render_figure(RUN, "phi_density_profile")
fig

# %%
fig = render_figure(RUN, "phi_potential_slice")
fig

# %%
fig = render_figure(RUN, "phi_density_slice")
fig

# %% [markdown]
# ## Validation
# Oracle and simulator-truth checks remain separate numeric validations. Their saved overlays can be registered without making generic figures depend on analytic truth.

# %% [markdown]
# ## Save the current figure
# Run exactly one of the following cells after rendering the figure you want.

# %%
write_figure(fig, target="debug")

# %%
# Confirm the figure before running this cell.
write_figure(fig, target="official")
